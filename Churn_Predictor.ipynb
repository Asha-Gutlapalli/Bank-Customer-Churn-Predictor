# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pickle

from keras.models import Sequential
from keras.layers import Dense, Dropout

# %% [markdown]
# ## Data Loading

# %%
dataset = pd.read_csv('data/Churn_Modelling.csv')
X = dataset.iloc[:, 3:13].values
Y = dataset.iloc[:, 13].values

dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ## Encoding

# %%
Encoder_X1 = LabelEncoder()
X[:, 1] = Encoder_X1.fit_transform(X[:, 1])

Encoder_X2 = LabelEncoder()
X[:, 2] = Encoder_X2.fit_transform(X[:, 2])

X.shape
# Out:
# (10000, 10)

# %% [markdown]
# ## Train-Test Split

# %%
Train_X, Test_X, Train_Y, Test_Y = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Scaling

# %%
sc = StandardScaler()

Train_X = sc.fit_transform(Train_X)
Test_X = sc.transform(Test_X)

# %% [markdown]
# ## Model

# %%
classifier = Sequential()
classifier.add(Dense(units = 32, activation = 'relu', input_dim = 10))
classifier.add(Dense(units = 16, activation = 'relu'))
classifier.add(Dense(units = 8, activation = 'relu'))
classifier.add(Dropout(0.4))
classifier.add(Dense(units = 1, activation = 'sigmoid'))

classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## Train

# %%
classifier.fit(Train_X, Train_Y, batch_size = 10, epochs = 200)
# Out:
# Epoch 1/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.2743 - accuracy: 0.8855
# Epoch 2/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.2721 - accuracy: 0.8907
# Epoch 3/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.2664 - accuracy: 0.8899
# Epoch 4/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.2686 - accuracy: 0.8874
# Epoch 5/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.2625 - accuracy: 0.8891
# Epoch 6/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.2665 - accuracy: 0.8905
# Epoch 7/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.2704 - accuracy: 0.8873
# Epoch 8/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.2676 - accuracy: 0.8889
# Epoch 9/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.2684 - accuracy: 0.8878
# Epoch 10/100
# ...

# %% [markdown]
# ## Save Model

# %%
classifier.save_weights("models/model")

# %% [markdown]
# ## Save Scaler

# %%
with open('scalers/scaler.pickle', 'wb') as handle:
    pickle.dump(sc, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Save Encoders

# %%
with open('encoders/encoder1.pickle', 'wb') as handle:
    pickle.dump(Encoder_X1, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('encoders/encoder2.pickle', 'wb') as handle:
    pickle.dump(Encoder_X2, handle, protocol=pickle.HIGHEST_PROTOCOL)
